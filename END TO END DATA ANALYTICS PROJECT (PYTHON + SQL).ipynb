# %%
# !pip install kaggle
import kaggle

# %%
#downloading the dataset frfom kaggle api
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv --force
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<?, ?B/s]

# %%
#extracting the files from zip file
import zipfile
zipfile = zipfile.ZipFile('archive (1).zip')
zipfile.extractall()
zipfile.close()

# %%
#reading the dataset
orders = pd.read_csv('orders.csv')
orders.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#handel the null values from Ship Mode
orders['Ship Mode'].unique()
#since 'Not Availiable','unknown' has the same meaning we will consider it as null
orders = pd.read_csv('orders.csv',na_values=['Not Available','unknown'])
orders['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#rename all column names make them lowercase and replace the space with underscore
orders.columns = orders.columns.str.replace(' ','_').str.lower()
orders.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#derive new columns named discouts, sales and profit
orders['discount_price'] = orders['list_price']*orders['discount_percent']*0.01
orders['selling_price'] = orders['list_price']-orders['discount_price']
orders['sales'] = orders['selling_price']*orders['quantity']
orders['profit'] = orders['selling_price']-orders['cost_price']
#dropping columns cost_price,list_price,discount_percent
orders.drop(['cost_price','list_price','discount_percent'],axis=1, inplace=True)
orders
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
#Convert order date column into date from object
orders['order_date'] = pd.to_datetime(orders['order_date'])
orders['order_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Load data into sql server usingreplace option
import sqlalchemy as sal
eng = sal.create_engine('mssql://LAPTOP-HTDMD154\MITESH/ankitbansal?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=eng.connect()

# %%
orders.to_sql('orders_etl',con=conn,if_exists='replace',index=False)
# Out:
# -1
